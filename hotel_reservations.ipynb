# %% [markdown]
# # **Data Exploration**

# %% [markdown]
# ### Import necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Load the data

# %%
df = pd.read_csv('hotel_reservations.csv')

# %% [markdown]
# ### Display the data

# %%
df
# Out:
#       Booking_ID  no_of_adults  no_of_children  no_of_weekend_nights  \
# 0       INN00001             2               0                     1
# 1       INN00002             2               0                     2
# 2       INN00003             1               0                     2
# 3       INN00004             2               0                     0
# 4       INN00005             2               0                     1
# ...          ...           ...             ...                   ...
# 36270   INN36271             3               0                     2
# 36271   INN36272             2               0                     1
# 36272   INN36273             2               0                     2
# 36273   INN36274             2               0                     0
# 36274   INN36275             2               0                     1
#
#        no_of_week_nights type_of_meal_plan  required_car_parking_space  \
# ...

# %% [markdown]
# ### Get information about the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36275 entries, 0 to 36274
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Booking_ID                            36275 non-null  object
#  1   no_of_adults                          36275 non-null  int64
#  2   no_of_children                        36275 non-null  int64
#  3   no_of_weekend_nights                  36275 non-null  int64
#  4   no_of_week_nights                     36275 non-null  int64
#  5   type_of_meal_plan                     36275 non-null  object
#  6   required_car_parking_space            36275 non-null  int64
#  7   room_type_reserved                    36275 non-null  object
#  8   lead_time                             36275 non-null  int64
#  9   arrival_year                          36275 non-null  int64
#  10  arrival_month                         36275 non-null  int64
# ...

# %% [markdown]
# ### Get description of the data

# %%
df.describe()
# Out:
#        no_of_adults  no_of_children  no_of_weekend_nights  no_of_week_nights  \
# count  36275.000000    36275.000000          36275.000000       36275.000000
# mean       1.844962        0.105279              0.810724           2.204300
# std        0.518715        0.402648              0.870644           1.410905
# min        0.000000        0.000000              0.000000           0.000000
# 25%        2.000000        0.000000              0.000000           1.000000
# 50%        2.000000        0.000000              1.000000           2.000000
# 75%        2.000000        0.000000              2.000000           3.000000
# max        4.000000       10.000000              7.000000          17.000000
#
#        required_car_parking_space     lead_time  arrival_year  arrival_month  \
# count                36275.000000  36275.000000  36275.000000   36275.000000
# mean                     0.030986     85.232557   2017.820427       7.423653
# ...

# %% [markdown]
# ### Check for null values

# %%
df.isnull().sum()
# Out:
# Booking_ID                              0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %% [markdown]
# ### Check for unique values

# %%
df.nunique()
# Out:
# Booking_ID                              36275
# no_of_adults                                5
# no_of_children                              6
# no_of_weekend_nights                        8
# no_of_week_nights                          18
# type_of_meal_plan                           4
# required_car_parking_space                  2
# room_type_reserved                          7
# lead_time                                 352
# arrival_year                                2
# arrival_month                              12
# arrival_date                               31
# market_segment_type                         5
# repeated_guest                              2
# no_of_previous_cancellations                9
# no_of_previous_bookings_not_canceled       59
# avg_price_per_room                       3930
# no_of_special_requests                      6
# booking_status                              2
# dtype: int64

# %% [markdown]
# ### Display all the columns

# %%
df.columns
# Out:
# Index(['Booking_ID', 'no_of_adults', 'no_of_children', 'no_of_weekend_nights',
#        'no_of_week_nights', 'type_of_meal_plan', 'required_car_parking_space',
#        'room_type_reserved', 'lead_time', 'arrival_year', 'arrival_month',
#        'arrival_date', 'market_segment_type', 'repeated_guest',
#        'no_of_previous_cancellations', 'no_of_previous_bookings_not_canceled',
#        'avg_price_per_room', 'no_of_special_requests', 'booking_status'],
#       dtype='object')

# %% [markdown]
# ### Display the type of every column

# %%
df.dtypes
# Out:
# Booking_ID                               object
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                        object
# required_car_parking_space                int64
# room_type_reserved                       object
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                      object
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# booking_status                           object
# dtype: object

# %% [markdown]
# ### List categories of every categorical column

# %%
df['no_of_adults'].value_counts()
# Out:
# no_of_adults
# 2    26108
# 1     7695
# 3     2317
# 0      139
# 4       16
# Name: count, dtype: int64

# %%
df['no_of_children'].value_counts()
# Out:
# no_of_children
# 0     33577
# 1      1618
# 2      1058
# 3        19
# 9         2
# 10        1
# Name: count, dtype: int64

# %%
df['type_of_meal_plan'].value_counts()
# Out:
# type_of_meal_plan
# Meal Plan 1     27835
# Not Selected     5130
# Meal Plan 2      3305
# Meal Plan 3         5
# Name: count, dtype: int64

# %%
df['room_type_reserved'].value_counts()
# Out:
# room_type_reserved
# Room_Type 1    28130
# Room_Type 4     6057
# Room_Type 6      966
# Room_Type 2      692
# Room_Type 5      265
# Room_Type 7      158
# Room_Type 3        7
# Name: count, dtype: int64

# %% [markdown]
# # **Data Visualization**

# %% [markdown]
# ### Import necessary libraries

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Distribution of target column

# %%
class_1_data = df[df['booking_status'] == 'Canceled']
class_2_data = df[df['booking_status'] == 'Not_Canceled']

plt.figure(figsize=(10, 6))

plt.hist(class_1_data['booking_status'], bins=5, alpha=0.5, color='blue', label='Cancelled')
plt.hist(class_2_data['booking_status'], bins=5, alpha=0.5, color='red', label='Not_Cancelled')

plt.xlabel('Booking Status')
plt.ylabel('Frequency')
plt.title('Distribution of Classes')
plt.legend()

plt.show()

# %% [markdown]
# ### Distribution of numerical columns

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['no_of_adults'], bins=15, alpha=0.5, color='green')

plt.xlabel('Number of Adults')
plt.ylabel('Frequency')
plt.title('Distribution of no_of_adults Column')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['no_of_children'], bins=20, alpha=0.5, color='green')

plt.xlabel('Number of Children')
plt.ylabel('Frequency')
plt.title('Distribution of no_of_children Column')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['no_of_weekend_nights'], bins=20, alpha=0.5, color='green')

plt.xlabel('Number of Weekend Nights')
plt.ylabel('Frequency')
plt.title('Distribution of no_of_weekend_nights Column')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['no_of_week_nights'], bins=40, alpha=0.5, color='green')

plt.xlabel('Number of Week Nights')
plt.ylabel('Frequency')
plt.title('Distribution of no_of_week_nights Column')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['required_car_parking_space'], bins=40, alpha=0.5, color='green')

plt.xlabel('Is Car Parking Space Required? (0-NO, 1-YES)')
plt.ylabel('Frequency')
plt.title('Distribution of required_car_parking_space Column')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['lead_time'], bins=40, alpha=0.5, color='green')

plt.xlabel('Lead Time')
plt.ylabel('Frequency')
plt.title('Distribution of lead_time Column')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['arrival_year'], bins=40, alpha=0.5, color='green')

plt.xlabel('Arrival Date (Year)')
plt.ylabel('Frequency')
plt.title('Distribution of arrival_year Column')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['arrival_month'], bins=40, alpha=0.5, color='green')

plt.xlabel('Arrival Date (Month)')
plt.ylabel('Frequency')
plt.title('Distribution of arrival_month Column')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['arrival_date'], bins=65, alpha=0.5, color='green')

plt.xlabel('Arrival Date (Day)')
plt.ylabel('Frequency')
plt.title('Distribution of arrival_date Column')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['repeated_guest'], bins=65, alpha=0.5, color='green')

plt.xlabel('Is the Guest Repeated? (0-NO, 1-YES)')
plt.ylabel('Frequency')
plt.title('Distribution of repeated_guest Column')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['no_of_previous_cancellations'], bins=65, alpha=0.5, color='green')

plt.xlabel('Number of Previous Cancellations')
plt.ylabel('Frequency')
plt.title('Distribution of no_of_previous_cancellations Column')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['no_of_previous_bookings_not_canceled'], bins=65, alpha=0.5, color='green')

plt.xlabel('Number of Previous Bookings not Canceled')
plt.ylabel('Frequency')
plt.title('Distribution of no_of_previous_bookings_not_canceled Column')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['avg_price_per_room'], bins=65, alpha=0.5, color='green')

plt.xlabel('Average Price per Room')
plt.ylabel('Frequency')
plt.title('Distribution of avg_price_per_room Column')

plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.hist(df['no_of_special_requests'], bins=65, alpha=0.5, color='green')

plt.xlabel('Number of Special Requests')
plt.ylabel('Frequency')
plt.title('Distribution of no_of_special_requests Column')

plt.show()

# %% [markdown]
# ### Distribution of categorical features

# %%
category_counts = df['type_of_meal_plan'].value_counts()

plt.figure(figsize=(10, 6))

category_counts.plot(kind='bar', color='skyblue')

plt.xlabel('Categories')
plt.ylabel('Frequency')
plt.title('Frequency of Categories in type_of_meal_plan')

plt.show()

# %%
category_counts = df['room_type_reserved'].value_counts()

plt.figure(figsize=(10, 6))

category_counts.plot(kind='bar', color='skyblue')

plt.xlabel('Categories')
plt.ylabel('Frequency')
plt.title('Frequency of Categories in room_type_reserved')

plt.show()

# %%
category_counts = df['market_segment_type'].value_counts()

plt.figure(figsize=(10, 6))

category_counts.plot(kind='bar', color='skyblue')

plt.xlabel('Categories')
plt.ylabel('Frequency')
plt.title('Frequency of Categories in market_segment_type')

plt.show()

# %% [markdown]
# # **Data Mining**

# %% [markdown]
# ### Import necessary libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

# %% [markdown]
# ### Extract features (X) and labels (y)

# %%
X = df.drop(columns=['booking_status'])  # Assuming 'target_column' is the column containing labels
y = df['booking_status']

# %% [markdown]
# ### Drop 'Booking_ID' column

# %%
X = X.drop(columns=['Booking_ID'])

# %% [markdown]
# ### Perform one-hot encoding for categorical variables

# %%
X_encoded = pd.get_dummies(X)

# %% [markdown]
# ### Split data into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Initialize SVM classifier

# %%
svm_classifier = SVC(kernel='linear')

# %% [markdown]
# ### Train SVM

# %%
svm_classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ### Make predictions

# %%
y_pred = svm_classifier.predict(X_test)

# %% [markdown]
# # **Model Evaluation**

# %% [markdown]
# ### Import necessary libraries

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %% [markdown]
# ### Compute accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)

# %% [markdown]
# ### Compute precision

# %%
precision = precision_score(y_test, y_pred, average='weighted')

# %% [markdown]
# ### Compute recall

# %%
recall = recall_score(y_test, y_pred, average='weighted')

# %% [markdown]
# ### Compute F1-score

# %%
f1 = f1_score(y_test, y_pred, average='weighted')

# %% [markdown]
# ### Results

# %%
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-score:", f1)
# Out:
# Accuracy: 0.8048242591316334
# Precision: 0.8005509190458465
# Recall: 0.8048242591316334
# F1-score: 0.8004397763319314
